# %%
from beneath.client import Client
client = Client(os.environ["BENEATH_SECRET"])
stream = client.stream(project="maker", stream="dai-transfers")
df = stream.load_all()

# %%
df
# Out:
#                                            from  index      name  \
# 0    0x5c87915f26b5414e9748300caa7a67f5f0c1b989    126  Transfer
# 1    0x3a32292c53bf42b6317334392bf0272da2983252    130  Transfer
# 2    0x35f5bbb9f0dea7d09cf6ec594bf79b15d7a099cb     29  Transfer
# 3                                          None    134      Mint
# 4    0x526af336d614ade5cc252a407062b8861af998f5    137  Transfer
# 5    0x6f858d52ff946d3a4c91fe5a7cdc408212d17a1b     86  Transfer
# 6    0x9ae49c0d7f8f9ef4b864e004fe86ac8294e20950     87  Transfer
# 7    0x04a487afd662c4f9deacc07a7b10cfb686b682a4     88  Transfer
# 8    0xd23654347cd7b25849ad32bdcf1c0b31e2785327    116  Transfer
# 9    0x4e5781b6ebafae7cb77f76452c93224cfc15a20c    130  Transfer
# 10   0x512fce9b07ce64590849115ee6b32fd40ec0f5f3    131  Transfer
# 11   0x630b9ba88169dd1832f361f5be5d1681fce858e8    156  Transfer
# 12   0x0d01d3ee3fd5e2bcde505caac40c354f4c92c6d1     31  Transfer
# ...
